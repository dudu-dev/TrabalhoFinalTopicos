# %%
import matplotlib.pyplot as plt

# Exemplo: substitua pelos seus próprios valores se não usou as variáveis acima
losses_lstm = [0.324739, 0.227839, 0.131802, 0.055939, 0.039241, 0.033773, 0.030036, 0.030186, 0.027349, 0.026366]
losses_gru =  [0.387471, 0.317514, 0.236915, 0.128592, 0.042578, 0.045368, 0.030371, 0.032717, 0.028847, 0.028569]

plt.figure(figsize=(10, 5))
plt.plot(losses_lstm, label='LSTM', marker='o')
plt.plot(losses_gru, label='GRU', marker='o')
plt.title('Comparação da perda (loss) durante o treino')
plt.xlabel('Época')
plt.ylabel('Loss')
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
